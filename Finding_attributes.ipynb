# %%
# Import the pandas library
import pandas as pd

import json


# Open the JSON file
with open(r'/content/sample_data/outputfull.json', 'r') as f:
    # Load the data from the file
    data = json.load(f)

# %%
keyslist=[]
for item in data:
    p_attributes = item['p_attributes']
    # p_attributes is a string representation of a dictionary, so we need to convert it to a dictionary object
    p_attributes = eval(p_attributes)  # use caution when using eval()
    # get all the keys in the dictionary
    keys = p_attributes.keys()
    keyslist.extend(keys)

# %%
len(keyslist)
# Out:
# 291336

# %%
Uniquekeys=list(set(keyslist))

# %%
len(Uniquekeys)
# Out:
# 106

# %%
# create a Pandas Series from the list
s = pd.Series(keyslist)
# get the count of each value in the Series
counts = s.value_counts()
# convert the Series to a DataFrame
df = counts.reset_index()
# rename the columns
df.columns = ['value', 'count']

# %%
df_sorted = df.sort_values('count',ascending=False)

# %%
df_sorted
# Out:
#                           value  count
# 0                      Occasion  13169
# 1                     Wash Care  13059
# 2                   Sustainable  12967
# 3          Body or Garment Size  10916
# 4                       Pattern  10463
# ..                          ...    ...
# 101                Pattern Size    103
# 102             Collection Name     75
# 103             About the Brand     36
# 104  How to care for your denim      6
# 105  What it does for your body      1
#
# [106 rows x 2 columns]
